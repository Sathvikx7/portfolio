# %% [markdown]
# <a href="https://colab.research.google.com/github/Sathvikx7/portfolio/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = np.array([1,2],[3,4])
b = np.array([5,6],[7,8])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3851/2516062298.py in <cell line: 0>()
# ----> 1 a = np.array([1,2],[3,4])
#       2 b = np.array([5,6],[7,8])
#
# NameError: name 'np' is not defined
